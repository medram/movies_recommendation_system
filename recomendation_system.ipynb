# %% [markdown]
# # <center>Movie Recommendation Systems</center>
#
# So, let’s make a real world Movie Recommendation System ourselves.
#
# ### Requirements:
# - Data/Dataset: https://www.kaggle.com/code/rounakbanik/movie-recommender-systems/input
# - Programming language: Python v3.9 or higher.
# - IDE / environment: Jupiter Notebook.
# - Python Packages: Numpy, Pandas, scikit-learn.
#
#
# Our Movie Recommendation System is going to include the following:
# - Classic / simple recommender system.
# - Content-based recommender system.
# - Metadata-based recommender system.
# - User-based recommender system (Hybrid Approaches).

# %% [markdown]
# # Data Preparation
# First, we need to load & clean up the date before start using it.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
movies_df = pd.read_csv("data/movies_metadata.csv", low_memory=False)

movies_df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# 45465                                   NaN  461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45461                fa                      رگ خواب
# 45462                tl          Siglo ng Pagluluwal
# 45463                en                     Betrayal
# 45464                en          Satana likuyushchiy
# 45465                en                     Queerama
#
#                                                 overview  ... release_date  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1      When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2      A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3      Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4      Just when George Banks has recovered from his ...  ...   1995-02-10
# ...                                                  ...  ...          ...
# 45461        Rising and falling between a man and woman.  ...          NaN
# 45462  An artist struggles to finish his work while a...  ...   2011-11-17
# 45463  When one of her hits goes wrong, a professiona...  ...   2003-08-01
# 45464  In a small town live two brothers, one a minis...  ...   1917-10-21
# 45465  50 years after decriminalisation of homosexual...  ...   2017-06-09
#
#            revenue runtime                                   spoken_languages  \
# 0      373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1      262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2              0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4       76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...            ...     ...                                                ...
# 45461          0.0    90.0             [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45462          0.0   360.0                  [{'iso_639_1': 'tl', 'name': ''}]
# 45463          0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45464          0.0    87.0                                                 []
# 45465          0.0    75.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released          Roll the dice and unleash the excitement!
# 2      Released  Still Yelling. Still Fighting. Still Ready for...
# 3      Released  Friends are the people who let you be yourself...
# 4      Released  Just When His World Is Back To Normal... He's ...
# ...         ...                                                ...
# 45461  Released         Rising and falling between a man and woman
# 45462  Released                                                NaN
# 45463  Released                             A deadly game of wits.
# 45464  Released                                                NaN
# 45465  Released                                                NaN
#
#                              title  video vote_average vote_count
# 0                        Toy Story  False          7.7     5415.0
# 1                          Jumanji  False          6.9     2413.0
# 2                 Grumpier Old Men  False          6.5       92.0
# 3                Waiting to Exhale  False          6.1       34.0
# 4      Father of the Bride Part II  False          5.7      173.0
# ...                            ...    ...          ...        ...
# 45461                       Subdue  False          4.0        1.0
# 45462          Century of Birthing  False          9.0        3.0
# 45463                     Betrayal  False          3.8        6.0
# 45464             Satan Triumphant  False          0.0        0.0
# 45465                     Queerama  False          0.0        0.0
#
# [45466 rows x 24 columns]

# %% [markdown]
# Removing / excluding unnecessary columns.

# %%
movies_df.drop(columns=[
    "homepage",
    "poster_path",
    "release_date",
    "runtime",
    "revenue", 
    "video", 
    "status", 
    "spoken_languages", 
    "belongs_to_collection", 
    "production_countries", 
    "original_language", 
    "original_title", 
    #"production_companies",
    "imdb_id",
    "popularity",
    "budget",
    "adult"
], inplace=True)

# %%
movies_df.dropna(subset=["title", "vote_average", "vote_count"], inplace=True)
movies_df["tagline"].replace(np.nan, "", inplace=True)
movies_df["overview"].replace(np.nan, "", inplace=True)

# %% [markdown]
# Formating `genres` and `production_companies` as a python list

# %%
movies_df["genres"] = movies_df["genres"].apply(eval).apply(lambda l: [f"{d['name']}" for d in l] if isinstance(l, list) else [])
movies_df["production_companies"] = movies_df["production_companies"].apply(eval).apply(lambda l: [f"{d['name']}" for d in l] if isinstance(l, list) else [])

# %% [markdown]
# Casting `id` and `cote_count` columns into integers values

# %%
#movies_df["adult"] = movies_df["adult"].apply(lambda x: True if x == "True" else False).astype(bool)
movies_df["id"] = movies_df["id"].astype(int)
movies_df["vote_count"] = movies_df["vote_count"].astype(int)

# %%
movies_df.isnull().sum()
# Out:
# genres                  0
# id                      0
# overview                0
# production_companies    0
# tagline                 0
# title                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %%
movies_df.dtypes
# Out:
# genres                   object
# id                        int64
# overview                 object
# production_companies     object
# tagline                  object
# title                    object
# vote_average            float64
# vote_count                int64
# dtype: object

# %% [markdown]
# #### Now `movies_df` is a clean dataframe.

# %%
movies_df.head()
# Out:
#                          genres     id  \
# 0   [Animation, Comedy, Family]    862
# 1  [Adventure, Fantasy, Family]   8844
# 2             [Romance, Comedy]  15602
# 3      [Comedy, Drama, Romance]  31357
# 4                      [Comedy]  11862
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                                 production_companies  \
# 0                          [Pixar Animation Studios]
# 1  [TriStar Pictures, Teitler Film, Interscope Co...
# 2                     [Warner Bros., Lancaster Gate]
# 3           [Twentieth Century Fox Film Corporation]
# 4       [Sandollar Productions, Touchstone Pictures]
#
#                                              tagline  \
# 0
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  vote_average  vote_count
# 0                    Toy Story           7.7        5415
# 1                      Jumanji           6.9        2413
# 2             Grumpier Old Men           6.5          92
# 3            Waiting to Exhale           6.1          34
# 4  Father of the Bride Part II           5.7         173

# %% [markdown]
# <hr>
# <br>
# <br>
#
# # Classic / Simple recommender System
#
# Now, let create a classic / simple recommender system, <br>to do so, we need to give / create a score for each movie to sort by, as well as adding the ability to filter by `genre`.

# %%
# Simple Recommender System

# Calculating the score
def score(vote_average, vote_count):
    return np.log((vote_average * vote_count) + 1)

def simple_recommender(df, n_results=10, genre=None):
    # make a copy of the data first
    df = df.copy()
    # Filter by genres.
    if isinstance(genre, (list, tuple)):
        df = df[df['genres'].apply(lambda x: set(genre) <= set(eval(str(x))))] # is a subset
    elif genre is not None:
        df = df[df['genres'].apply(lambda x: genre in str(x))]
    
    # Calgulating the score
    df["score"] = score(df['vote_average'], df['vote_count'])
    df.sort_values(by='score', ascending=False, ignore_index=True, inplace=True)
    
    return df.head(n_results)

# %%
simple_recommender(movies_df, n_results=10, genre=["Action", "Drama"])
# Out:
#                                               genres      id  \
# 0                   [Drama, Action, Crime, Thriller]     155
# 1                   [Action, Crime, Drama, Thriller]   49026
# 2                             [Action, Crime, Drama]     272
# 3                     [Drama, Action, Thriller, War]   16869
# 4                   [Action, Drama, Science Fiction]  263115
# 5                         [Action, Drama, Adventure]      98
# 6                         [Adventure, Drama, Action]   87827
# 7  [Action, Drama, Horror, Science Fiction, Thril...   72190
# 8  [Drama, Horror, Action, Thriller, Science Fict...    6479
# 9         [Science Fiction, Action, Drama, Thriller]  119450
#
#                                             overview  \
# 0  Batman raises the stakes in his war on crime. ...
# 1  Following the death of District Attorney Harve...
# 2  Driven by tragedy, billionaire Bruce Wayne ded...
# 3  In Nazi-occupied France during World War II, a...
# 4  In the near future, a weary Logan cares for an...
# 5  In the year 180, the death of emperor Marcus A...
# 6  The story of an Indian boy named Pi, a zookeep...
# 7  Life for former United Nations investigator Ge...
# 8  Robert Neville is a scientist who was unable t...
# 9  A group of scientists in San Francisco struggl...
#
#                                 production_companies  \
# 0  [DC Comics, Legendary Pictures, Warner Bros., ...
# 1  [Legendary Pictures, Warner Bros., DC Entertai...
# 2  [DC Comics, Legendary Pictures, Warner Bros., ...
# 3  [Universal Pictures, A Band Apart, The Weinste...
# 4  [Twentieth Century Fox Film Corporation, Donne...
# 5  [DreamWorks SKG, Universal Pictures, Scott Fre...
# 6  [Ingenious Film Partners, Ingenious Media, Dun...
# 7  [Paramount Pictures, GK Films, Skydance Produc...
# 8  [Village Roadshow Pictures, Original Film, Wee...
# 9  [Ingenious Media, Chernin Entertainment, TSG E...
#
#                                        tagline  \
# 0                              Why So Serious?
# 1                              The Legend Ends
# 2                       Evil fears the knight.
# 3  Once upon a time in Nazi occupied France...
# 4                            His time has come
# 5                            A Hero Will Rise.
# 6                     Believe The Unbelievable
# 7                             Remember Philly!
# 8           The last man on Earth is not alone
# 9                   One last chance for peace.
#
#                             title  vote_average  vote_count      score
# 0                 The Dark Knight           8.3       12269  11.531096
# 1           The Dark Knight Rises           7.6        9263  11.161946
# 2                   Batman Begins           7.5        7511  10.939045
# 3            Inglourious Basterds           7.9        6598  10.861404
# 4                           Logan           7.6        6310  10.778060
# 5                       Gladiator           7.9        5566  10.691317
# 6                      Life of Pi           7.2        5912  10.658844
# 7                     World War Z           6.7        5683  10.547368
# 8                     I Am Legend           6.9        4977  10.444133
# 9  Dawn of the Planet of the Apes           7.3        4511  10.402179

# %% [markdown]
# As you can see in the table above, we've added the `score` column, and the results are sorted in desending order,<br>
# and that brought us the Best Movies of all time for `action` and `drama` genres.
#
# ## Simple Recommender System usage / benefits:
# - This type of Recommendation System (classic one) comes in handy / useful for showing `Trending`, or `Trending per genre`.
# - Useful for making suggestions for new users (Those who have no history or preferences yet).

# %% [markdown]
# <hr>
# <br>
# <br>
#
# # Content-Based Recommender System
#
# In this type of recommendation system we're going to focus on movies content (e.g. `title`, `tagline`, `production_companies`, `overview`)<br>
# This type of recommendation is a little bit computation hangry, so to achieve that, we do the following:<br>
#
#
# - To address issue of the required computation power, not all the movies are going to be in the recommendation system,<br>
# so, let's set a `vote` and `vote_count` threshold as a movie minimum requirements in order to enter the recommandation system.
# - Once we got our movies dataframe `reduced_df` that is going to be used for recommendation system, <br>
# We can use `TfidfVectorizer` from sklearn to convert text into vectors, this process called vectorazation / embedding.
# - We got a `matrix` that represents `reduced_df` after the vectorazation process.<br>
# by the way, this matrix could be caled a vector database or a vectorstore.
# - moreover, we calculate a similarity score for each movie after vectorizing the `query` input.
# - in the end, we append the `cos_similarity` column to the result dataframe, then sorting the last one on the descending order.

# %%
# Functions will be needed later

# returns an interger value (-1 to 1).
def cos_similarity(matrix, vec):
    return (matrix @ vec.T) / np.sqrt(np.sum(matrix ** 2, axis=1) * np.sum(vec.T ** 2, axis=0))

# %%
# Content Based Recommender System.
from sklearn.feature_extraction.text import TfidfVectorizer

# data needs to be reduced.
threshold = movies_df['vote_count'].quantile(0.95)
vote_mean = movies_df['vote_average'].mean() / 2

print("Vote_count threshold:", threshold)
print("Vote mean:", vote_mean)
reduced_df = movies_df[(movies_df['vote_count'] >= threshold) & (movies_df['vote_average'] >= vote_mean)] 

reduced_df = reduced_df.reset_index(drop=True)

print("Dataframe size: %s rows" % reduced_df.shape[0])


# Making a Vector database.
tf = TfidfVectorizer(analyzer='word', stop_words='english')

descriptions = reduced_df.apply(lambda s: f"{s['title']} {s['tagline']} {s['production_companies']} {s['overview']}", axis=1)
matrix = tf.fit_transform(descriptions).toarray()


def content_based_recommender(query, df, n_results=10):
    df = df.copy()

    # Calculate the similarity (cosine)
    vec = tf.transform([query]).toarray().ravel()
    
    # Append & sort to dataframe
    df['cos_similarity'] = cos_similarity(matrix, vec)
    df.sort_values(by='cos_similarity', ascending=False, ignore_index=True, inplace=True)

    return df.head(n_results)
# Out:
# Vote_count threshold: 434.0
# Vote mean: 2.8091036075669447
# Dataframe size: 2274 rows

# %%
content_based_recommender("Batman", reduced_df, n_results=10)
# Out:
#                                          genres      id  \
# 0                             [Action, Fantasy]     364
# 1  [Action, Animation, Comedy, Family, Fantasy]  324849
# 2                           [Action, Animation]   40662
# 3                      [Action, Crime, Fantasy]     414
# 4             [Action, Animation, Crime, Drama]  382322
# 5                        [Action, Crime, Drama]     272
# 6              [Drama, Action, Crime, Thriller]     155
# 7                      [Action, Crime, Fantasy]     415
# 8                  [Action, Adventure, Fantasy]  209112
# 9              [Action, Crime, Drama, Thriller]   49026
#
#                                             overview  \
# 0  Having defeated the Joker, Batman now faces th...
# 1  In the irreverent spirit of fun that made “The...
# 2  Batman faces his ultimate challenge as the mys...
# 3  The Dark Knight of Gotham City confronts a das...
# 4  As Batman hunts for the escaped Joker, the Clo...
# 5  Driven by tragedy, billionaire Bruce Wayne ded...
# 6  Batman raises the stakes in his war on crime. ...
# 7  Along with crime-fighting partner Robin and ne...
# 8  Fearing the actions of a god-like Super Hero l...
# 9  Following the death of District Attorney Harve...
#
#                                 production_companies  \
# 0      [PolyGram Filmed Entertainment, Warner Bros.]
# 1  [Lin Pictures, Warner Bros. Animation, Warner ...
# 2                [DC Comics, Warner Bros. Animation]
# 3      [Warner Bros., Polygram Filmed Entertainment]
# 4                [DC Comics, Warner Bros. Animation]
# 5  [DC Comics, Legendary Pictures, Warner Bros., ...
# 6  [DC Comics, Legendary Pictures, Warner Bros., ...
# 7      [PolyGram Filmed Entertainment, Warner Bros.]
# 8  [DC Comics, Atlas Entertainment, Warner Bros.,...
# 9  [Legendary Pictures, Warner Bros., DC Entertai...
#
#                                          tagline  \
# 0                 The Bat, the Cat, the Penguin.
# 1  Always be yourself. Unless you can be Batman.
# 2                 Dare to Look Beneath the Hood.
# 3                   Courage now, truth always...
# 4                            The madness begins.
# 5                         Evil fears the knight.
# 6                                Why So Serious?
# 7         Strength. Courage. Honor. And loyalty.
# 8                             Justice or revenge
# 9                                The Legend Ends
#
#                                 title  vote_average  vote_count  \
# 0                      Batman Returns           6.6        1706
# 1               The Lego Batman Movie           7.2        1473
# 2          Batman: Under the Red Hood           7.6         459
# 3                      Batman Forever           5.2        1529
# 4            Batman: The Killing Joke           6.2         485
# 5                       Batman Begins           7.5        7511
# 6                     The Dark Knight           8.3       12269
# 7                      Batman & Robin           4.2        1447
# 8  Batman v Superman: Dawn of Justice           5.7        7189
# 9               The Dark Knight Rises           7.6        9263
#
#    cos_similarity
# 0        0.536871
# 1        0.433553
# 2        0.401840
# 3        0.369199
# 4        0.339751
# 5        0.325422
# 6        0.292171
# 7        0.281644
# 8        0.270846
# 9        0.261025

# %% [markdown]
# As you can see in the table above, using `Batman` as a query input leads in a best relevant results like:
# - Batman Returns
# - The Lego Batman Movie
# - Batman: Under the Red Hood
# - Batman Forever
# - Batman: The Killing Joke
# - The Dark Knight
# - The Dark Knight Rises
# So far everything is working as intended.
#
# ## Content-Based Recommender System Usage / Benefits:
# This type of recommendation system is powerful and has various applications, for example:
# - Could be used as an advanced web search engine.
# - `Giving relevent (ads/posts/videos/products) recommendations basing on sound/microphone inputs as a query input (the same technique has been adopted by Facebook, Google & Amazon)`

# %% [markdown]
# <br>
# <hr>
# <br>
# <br>
#
# # Metadata-Based Recommender System
#
# We perform the same approach as the content-based recommendation but for movies metadata.

# %%
# Metadata recommender System

credits_df = pd.read_csv("data/credits.csv")

credits_df
# Out:
#                                                     cast  \
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4      [{'cast_id': 1, 'character': 'George Banks', '...
# ...                                                  ...
# 45471  [{'cast_id': 0, 'character': '', 'credit_id': ...
# 45472  [{'cast_id': 1002, 'character': 'Sister Angela...
# 45473  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 45474  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45475                                                 []
#
#                                                     crew      id
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...     862
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...    8844
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...   15602
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...   31357
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'de...   11862
# ...                                                  ...     ...
# 45471  [{'credit_id': '5894a97d925141426c00818c', 'de...  439050
# 45472  [{'credit_id': '52fe4af1c3a36847f81e9b15', 'de...  111109
# 45473  [{'credit_id': '52fe4776c3a368484e0c8387', 'de...   67758
# 45474  [{'credit_id': '533bccebc3a36844cf0011a7', 'de...  227506
# 45475  [{'credit_id': '593e676c92514105b702e68e', 'de...  461257
#
# [45476 rows x 3 columns]

# %%
# Useful functions

# Get movie first n casts from metadata dataframe
def get_movie_cast(s, limit=3):
    l = eval(str(s))
    return [f"{cast['name']} - {cast['character']}" for cast in l[:limit]]

# Get movie director from metadata dataframe
def get_movie_director(s):
    l = eval(str(s))
    return l[0]['name'] if l else ""

# Get a dataframe subset movies by movie ids
def get_movies_by_ids(df, ids, key='id'):
    return df[df[key].isin(ids)]

# %% [markdown]
# #### Cleaning up the credits/metadata dataframe.

# %%
casts = credits_df['cast'].apply(get_movie_cast)
directors = credits_df['crew'].apply(get_movie_director)

metadata_df = pd.DataFrame({"casts": casts, "director": directors, 'movie_id': credits_df['id'], 'genres': movies_df['genres']})

metadata_df.dropna(inplace=True)
metadata_df = metadata_df[metadata_df['movie_id'].isin(reduced_df['id'])]

metadata_df
# Out:
#                                                    casts         director  \
# 0      [Tom Hanks - Woody (voice), Tim Allen - Buzz L...    John Lasseter
# 1      [Robin Williams - Alan Parrish, Jonathan Hyde ...  Larry J. Franco
# 5      [Al Pacino - Lt. Vincent Hanna, Robert De Niro...     Michael Mann
# 9      [Pierce Brosnan - James Bond, Sean Bean - Alec...  Martin Campbell
# 15     [Robert De Niro - Sam 'Ace' Rothstein, Sharon ...  Martin Scorsese
# ...                                                  ...              ...
# 44634  [Noomi Rapace - Monday / Tuesday / Wednesday /...    Tommy Wirkola
# 44642  [Charlize Theron - Lorraine Broughton, James M...     David Leitch
# 44688  [Fionn Whitehead - Tommy, Tom Glynn-Carney - P...      Hans Zimmer
# 44852  [Mark Wahlberg - Cade Yeager, Josh Duhamel - C...   Akiva Goldsman
# 45024  [Idris Elba - Roland Deschain, Matthew McConau...     Brian Grazer
#
#        movie_id                            genres
# 0           862       [Animation, Comedy, Family]
# 1          8844      [Adventure, Fantasy, Family]
# 5           949  [Action, Crime, Drama, Thriller]
# 9           710     [Adventure, Action, Thriller]
# 15          524                    [Drama, Crime]
# ...         ...                               ...
# 44634    406990                       [Animation]
# 44642    341013                           [Drama]
# 44688    374720                                []
# 44852    335988                 [Drama, Thriller]
# 45024    353491        [Adventure, Drama, Family]
#
# [2273 rows x 4 columns]

# %%
# Create metadata content

# This function creates a text/string for each movie, this string is going to be vectorized.
def format_metadata(row):
    casts = ", ".join(eval(str(row['casts'])))
    genres = ", ".join(eval(str(row['genres'])))
    return f"{row['director']}, {casts}\n{genres}"

metadata_content = metadata_df.apply(format_metadata, axis=1)

metadata_content.head(10)
# Out:
# 0     John Lasseter, Tom Hanks - Woody (voice), Tim ...
# 1     Larry J. Franco, Robin Williams - Alan Parrish...
# 5     Michael Mann, Al Pacino - Lt. Vincent Hanna, R...
# 9     Martin Campbell, Pierce Brosnan - James Bond, ...
# 15    Martin Scorsese, Robert De Niro - Sam 'Ace' Ro...
# 17    Combustible Edison, Tim Roth - Ted the Bellhop...
# 18    Steve Oedekerk, Jim Carrey - Ace Ventura, Ian ...
# 31    Terry Gilliam, Bruce Willis - James Cole, Made...
# 33    Andrew Lesnie, Christine Cavanaugh - Babe the ...
# 38    Amy Heckerling, Alicia Silverstone - Cher Horo...
# dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tf2 = TfidfVectorizer(analyzer='word', stop_words='english')

matrix2 = tf2.fit_transform(metadata_content).toarray()


def metadata_recommender(query, df, n_results=10):
    df = df.copy()

    # Calculate the similarity (cosine)
    vec = tf2.transform([query]).toarray().ravel()
    
    # Append & sort to dataframe
    df['metadata_cos_similarity'] = cos_similarity(matrix2, vec)
    df.sort_values(by='metadata_cos_similarity', ascending=False, ignore_index=True, inplace=True)

    df = df.head(n_results)
    # Get movies titles
    df2 = get_movies_by_ids(reduced_df, df['movie_id'])[['title', 'vote_average', 'vote_count']]
    
    
    #df = df.assign(title=titles.tolist())
    df = df.assign(title=df2['title'].tolist(), vote_average=df2['vote_average'].tolist(), vote_count=df2['vote_count'].tolist())
    
    # reorder columns
    df = df.reindex(columns=['movie_id', 'title', 'director', 'genres', 'vote_average', 'vote_count', 'metadata_cos_similarity'])
    
    return df

# %%
metadata_recommender('Arnold Schwarzenegger', metadata_df, n_results=15)
# Out:
#     movie_id                               title            director  \
# 0      36955                           True Lies      Mark Goldblatt
# 1        280                    Last Action Hero           Dody Dorn
# 2       9593          Terminator 2: Judgment Day      John McTiernan
# 3        218                      The Terminator      Gale Anne Hurd
# 4        296                  Jingle All the Way     Jonathan Mostow
# 5       8452                 Conan the Barbarian        Trevor Rabin
# 6        861                        Total Recall      Paul Verhoeven
# 7     107846                         End of Days         David Lazan
# 8       9279                     The Running Man        David Newman
# 9      87101                         The 6th Day         Ronna Kress
# 10     10999  Terminator 3: Rise of the Machines      Mark L. Lester
# 11      9946                            Commando         Peter Hyams
# 12      9387                         Escape Plan         John Milius
# 13       865                  Terminator Genisys  Harold Faltermeyer
# 14    287424                              Maggie        Henry Hobson
#
#                                           genres  vote_average  vote_count  \
# 0                             [Action, Thriller]           6.8        1138
# 1            [Action, Thriller, Science Fiction]           6.1         725
# 2   [Adventure, Fantasy, Action, Comedy, Family]           7.7        4274
# 3            [Action, Thriller, Science Fiction]           7.4        4208
# 4            [Action, Thriller, Science Fiction]           5.5         583
# 5                              [Science Fiction]           6.6         663
# 6           [Action, Adventure, Science Fiction]           7.1        1745
# 7                                       [Horror]           5.5         488
# 8                               [Family, Comedy]           6.4         713
# 9                                [Comedy, Drama]           5.7         603
# 10                 [Action, Adventure, Thriller]           5.9        2177
# 11            [Action, Fantasy, Horror, Mystery]           6.4         753
# 12                  [Adventure, Fantasy, Action]           6.7        1688
# 13                     [Action, Science Fiction]           5.8        3677
# 14                                      [Action]           5.2         604
#
#     metadata_cos_similarity
# 0                  0.441730
# 1                  0.356553
# 2                  0.348099
# 3                  0.347082
# 4                  0.345141
# 5                  0.337804
# 6                  0.335016
# 7                  0.328579
# 8                  0.320551
# 9                  0.318810
# 10                 0.318734
# 11                 0.317616
# 12                 0.315755
# 13                 0.305970
# 14                 0.304221

# %% [markdown]
# <br>
#
# As you can see in the table above, we performed a search about `Arnold Schwarzenegger` and we got a very relevant movie results, all the movies mentioned in the results (table above) are `Arnold Schwarzenegger` movies, and that is great an proofs that the Metadata-Based recommendation system is working as intended.
#
# <br>
# <br>
# <hr>
# <br>

# %% [markdown]
# # User-Based Recommender System
#
# This type of recommendation system is based on user's preferences and history to delever much relevant suggesstions / recommendations.
#
# To achieve this, for each user we need to perform the followings:
# - Get user's movie preferences.
# - Exclude unliked user movies.
# - Vectorizing user movies (preferences).
# - Getting recommendations for that specific user based on his interest.

# %%
# Loading users data.

ratings_df = pd.read_csv("data/ratings_small.csv")

ratings_df
# Out:
#         userId  movieId  rating   timestamp
# 0            1       31     2.5  1260759144
# 1            1     1029     3.0  1260759179
# 2            1     1061     3.0  1260759182
# 3            1     1129     2.0  1260759185
# 4            1     1172     4.0  1260759205
# ...        ...      ...     ...         ...
# 99999      671     6268     2.5  1065579370
# 100000     671     6269     4.0  1065149201
# 100001     671     6365     4.0  1070940363
# 100002     671     6385     2.5  1070979663
# 100003     671     6565     3.5  1074784724
#
# [100004 rows x 4 columns]

# %%
# Get user's movie preferences by user ID. 
def get_user_ratings(id):
    return ratings_df[ratings_df['userId'] == id].sort_values('rating', ascending=False)


# Vectorizing users movies preferences, return a matrix.
def get_vectorized_user_movies(id, min_rating=5):
    user_df = get_user_ratings(id)
    user_df = user_df[user_df['rating'] >= min_rating]
    user_movies_df = get_movies_by_ids(reduced_df, user_df['movieId'])
    
    user_descriptions_df = user_movies_df.apply(lambda s: f"{s['title']} {s['tagline']} {s['production_companies']} {s['overview']}", axis=1)

    return tf.transform(user_descriptions_df).toarray()

# %%
# Getting movies that the user (id=28) has watched. 
user_id = 28

user_df = get_user_ratings(user_id)
user_df['rating'] = user_df['rating'] * 2
user_movies_df = get_movies_by_ids(reduced_df, user_df['movieId'])

user_movies_df.head(15)
# Out:
#                                            genres    id  \
# 97    [Animation, Comedy, Drama, Family, Fantasy]  2300
# 299                                       [Drama]  1366
# 351             [Action, Comedy, Crime, Thriller]  2109
# 417                              [Mystery, Drama]   345
# 466             [Comedy, Family, Science Fiction]   926
# 786                     [Fantasy, Horror, Action]   924
# 898                           [Family, Animation]   953
# 980        [Animation, Adventure, Comedy, Family]   920
# 984                  [Adventure, Fantasy, Action]    58
# 1035          [Thriller, Action, Fantasy, Horror]  1250
# 1047                  [Animation, Comedy, Family]  1267
#
#                                                overview  \
# 97    In a desperate attempt to win a basketball mat...
# 299   When world heavyweight boxing champion, Apollo...
# 351   When Hong Kong Inspector Lee is summoned to Lo...
# 417   After Dr. Bill Hartford's wife, Alice, admits ...
# 466   The stars of a 1970s sci-fi show - now scrapin...
# 786   A group of surviving people take refuge in a s...
# 898   Zoo animals leave the comforts of man-made hab...
# 980   Lightning McQueen, a hotshot rookie race car d...
# 984   Captain Jack Sparrow works his way out of a bl...
# 1035  In order to save his dying father, young stunt...
# 1047  In this animated adventure, brilliant preteen ...
#
#                                    production_companies  \
# 97    [Warner Bros. Family Entertainment, Northern L...
# 299                                    [United Artists]
# 351                                   [New Line Cinema]
# 417   [Hobby Films, Pole Star, Stanley Kubrick Produ...
# 466              [DreamWorks SKG, Gran Via Productions]
# 786   [New Amsterdam Entertainment, Strike Entertain...
# 898   [DreamWorks SKG, Pacific Data Images (PDI), Dr...
# 980     [Walt Disney Pictures, Pixar Animation Studios]
# 984   [Walt Disney Pictures, Jerry Bruckheimer Films...
# 1035  [Columbia Pictures Corporation, Relativity Med...
# 1047  [Walt Disney Pictures, Walt Disney Animation S...
#
#                                                 tagline  \
# 97                                    Get ready to jam.
# 299           His whole life was a million-to-one shot.
# 351   The Fastest Hands in the East Meet the Biggest...
# 417                            Cruise. Kidman. Kubrick.
# 466                   A comedy of Galactic Proportions.
# 786       When the undead rise, civilization will fall.
# 898                          Someone's got a zoo loose.
# 980              Ahhh... it's got that new movie smell.
# 984                                       Jack is back!
# 1035                      Hell Is About To Be Unleashed
# 1047                         Think your family's weird?
#
#                                            title  vote_average  vote_count
# 97                                     Space Jam           6.5        1335
# 299                                        Rocky           7.5        1843
# 351                                    Rush Hour           6.8        1254
# 417                               Eyes Wide Shut           7.1        1266
# 466                                 Galaxy Quest           6.9         722
# 786                             Dawn of the Dead           6.8        1039
# 898                                   Madagascar           6.6        3322
# 980                                         Cars           6.6        3991
# 984   Pirates of the Caribbean: Dead Man's Chest           7.0        5380
# 1035                                 Ghost Rider           5.2        1754
# 1047                          Meet the Robinsons           6.7         787

# %% [markdown]
# As you may noticed in the table above, the user with id=28 has watched the following movies (his favorate movies):
# - Rocky
# - Rush Hour
# - Cars
# - Ghost Rider
# - Pirates of the Caribbean: Dead Man's Chest
#
# #### <b>Note:</b> remember that this user has watched those movies (will need them later for comparison).

# %% [markdown]
# # OK, The Main Question is, How are We going to get Recommendations for that specific User?
#
# First, I would like to explain the concept, then see the coding.<br>
# - let's suppose that each movie could be represented with just `x` and `y` in a 2D space.
# - in the `figure-1`, after ploting user's favorite movies, we can draw a rectangle around those movies (using just minimum/maximum of `x` & `y`)
#
# <img src="imgs/figure_1.png" >
#
# - This rectangle is representing the user's movie interest, in other words, movies that fall inside this rectengle are a great match to the user's interest.
# - <b>So, any movie inside the rectengle could be used as a recommendation.</b>

# %% [markdown]
# <br>
# <br>
# Now, let vectorize his favorite movies (rating >= 5).

# %%
vectorized_user_df = get_vectorized_user_movies(user_id) # default: min_rating=5

vectorized_user_df.shape
# Out:
# (8, 16266)

# %%
matrix.shape
# Out:
# (2274, 16266)

# %% [markdown]
# #### To organize this, we could create a user class for it.

# %%
class User:
    def __init__(self, user_id, db_matrix, min_rating=5):
        self._db_matrix = db_matrix
        self._min_rating = min_rating
        
        self._user_df = get_user_ratings(user_id)
        # chanching the rating to be (0 to 10).
        self._user_df['rating'] = self._user_df['rating'] * 2
        self._rated_movies_df = get_movies_by_ids(reduced_df, self._user_df['movieId'])
        
    def rated_movies(self):
        return self._rated_movies_df
        
    def vectorized_rated_movies(self):
        # Getting just movies that are rated higher than min_rating. 
        user_df = self._user_df[self._user_df['rating'] >= self._min_rating]
        user_movies_df = get_movies_by_ids(reduced_df, user_df['movieId'])
        
        # Generate a user description to be vectorized. 
        user_descriptions_df = user_movies_df.apply(lambda s: f"{s['title']} {s['tagline']} {s['production_companies']} {s['overview']}", axis=1)
        
        # Vectorizing the user description.
        return tf.transform(user_descriptions_df).toarray()
    
    def recommendations(self, vec=None):
        '''
        Return movies recommendations based on user interest.
        '''
        if vec is None:
            vec = np.mean(self.vectorized_rated_movies(), axis=0)

        cos_sim = cos_similarity(self._db_matrix, vec)
        user_recommended_df = reduced_df.copy()
        user_recommended_df['user_cos_similarity'] = cos_sim
        
        # Exclude already watched movies from recommendations
        user_recommended_df = user_recommended_df[~user_recommended_df['id'].isin(self._user_df['movieId'])]
        
        # Sorting values based on cos_similarity.
        user_recommended_df.sort_values('user_cos_similarity', ascending=False, inplace=True)

        return user_recommended_df
        
    def variant_interest_vector(self):
        '''
        Return a random vector between top movie & good movie vectors, in other words, the same user interest.
        '''
        vec = self.vectorized_rated_movies()
        min_vec = vec.min(axis=0)
        max_vec = vec.max(axis=0)
        
        #user_space = max_vec - min_vec
        #print("user_space min:", user_space.min())
        #print("user_space max:", user_space.max())
        
        # Create a random vector with the same user interest.
        return np.array([np.random.uniform(min_v, max_v) for min_v, max_v in np.c_[min_vec, max_vec]]) 
    
    def variant_recommendations(self):
        '''
        Return movies recommendations randomly based on user interest.
        '''
        vec = self.variant_interest_vector()
        return self.recommendations(vec=vec)

# %%
user = User(28, matrix)

user.recommendations().head(10)
# Out:
#                                       genres      id  \
# 1058            [Adventure, Fantasy, Action]     285
# 1482  [Animation, Family, Adventure, Comedy]   49013
# 2104                                 [Drama]  312221
# 1466            [Adventure, Action, Fantasy]    1865
# 2263  [Family, Comedy, Animation, Adventure]  260514
# 1562             [Action, Fantasy, Thriller]   71676
# 1076       [Action, Comedy, Crime, Thriller]    5174
# 605        [Action, Comedy, Crime, Thriller]    5175
# 792                                 [Horror]     923
# 377                                  [Drama]    1375
#
#                                                overview  \
# 1058  Captain Barbossa, long believed to be dead, ha...
# 1482  Star race car Lightning McQueen and his pal Ma...
# 2104  The former World Heavyweight Champion Rocky Ba...
# 1466  Captain Jack Sparrow crosses paths with a woma...
# 2263  Blindsided by a new generation of blazing-fast...
# 1562  When the devil resurfaces with aims to take ov...
# 1076  After an attempted assassination on Ambassador...
# 605   It's vacation time for Carter as he finds hims...
# 792   During an ever-growing epidemic of zombies tha...
# 377   A lifetime of taking shots has ended Rocky's c...
#
#                                    production_companies  \
# 1058  [Walt Disney Pictures, Jerry Bruckheimer Films...
# 1482    [Walt Disney Pictures, Pixar Animation Studios]
# 2104  [New Line Cinema, Warner Bros., Metro-Goldwyn-...
# 1466  [Walt Disney Pictures, Jerry Bruckheimer Films...
# 2263    [Walt Disney Pictures, Pixar Animation Studios]
# 1562  [Columbia Pictures, Imagenation Abu Dhabi FZ, ...
# 1076                                  [New Line Cinema]
# 605                                   [New Line Cinema]
# 792                     [Laurel Group, Dawn Associates]
# 377                                    [United Artists]
#
#                                                 tagline  \
# 1058     At the end of the world, the adventure begins.
# 1482                                           Ka-ciao!
# 2104                    Your legacy is more than a name
# 1466                        Live Forever Or Die Trying.
# 2263           From this moment, everything will change
# 1562                                    He Rides Again.
# 1076                                    The Rush Is On!
# 605                        Get ready for a second Rush!
# 792   When there's no more room in hell, the dead wi...
# 377                                          Go for it!
#
#                                             title  vote_average  vote_count  \
# 1058     Pirates of the Caribbean: At World's End           6.9        4627
# 1482                                       Cars 2           5.8        2088
# 2104                                        Creed           7.3        1963
# 1466  Pirates of the Caribbean: On Stranger Tides           6.4        5068
# 2263                                       Cars 3           6.6         718
# 1562             Ghost Rider: Spirit of Vengeance           4.7        1163
# 1076                                  Rush Hour 3           6.1         801
# 605                                   Rush Hour 2           6.4        1078
# 792                              Dawn of the Dead           7.4         597
# 377                                       Rocky V           5.3         688
#
#       user_cos_similarity
# 1058             0.152797
# 1482             0.151770
# 2104             0.142251
# 1466             0.133030
# 2263             0.127239
# 1562             0.126549
# 1076             0.125648
# 605              0.116921
# 792              0.116142
# 377              0.113532

# %% [markdown]
# <br>
#
# As you may noticed in the table above, the user with id=28 who has watched the following movies:
# - Rocky
# - Rush Hour
# - Cars
# - Ghost Rider
# - Pirates of the Caribbean: Dead Man's Chest
#
# The User-Based Recommender System has suggested to him the following movies:
# - Cars 2
# - Rocky V
# - Cars 3
# - Rush Hour 2
# - Rush Hour 3
# - Pirates of the Caribbean: At World's End
# - Pirates of the Caribbean: On Stranger Tides
# - Ghost Rider: Spirit of Vengeance
#
# ### So, the user has got suggestions based on his interest, this is really great 😃.

# %%
# Randomized / Varianted recommendations
user.variant_recommendations().head(10)
# Out:
#                                       genres     id  \
# 1466            [Adventure, Action, Fantasy]   1865
# 1482  [Animation, Family, Adventure, Comedy]  49013
# 377                                  [Drama]   1375
# 727             [Adventure, Fantasy, Action]     22
# 1058            [Adventure, Fantasy, Action]    285
# 376                                  [Drama]   1374
# 1562             [Action, Fantasy, Thriller]  71676
# 1025                                 [Drama]   1246
# 792                                 [Horror]    923
# 374                                  [Drama]   1367
#
#                                                overview  \
# 1466  Captain Jack Sparrow crosses paths with a woma...
# 1482  Star race car Lightning McQueen and his pal Ma...
# 377   A lifetime of taking shots has ended Rocky's c...
# 727   Jack Sparrow, a freewheeling 17th-century pira...
# 1058  Captain Barbossa, long believed to be dead, ha...
# 376   Rocky must come out of retirement to battle a ...
# 1562  When the devil resurfaces with aims to take ov...
# 1025  When he loses a highly publicized virtual boxi...
# 792   During an ever-growing epidemic of zombies tha...
# 374   After Rocky goes the distance with champ Apoll...
#
#                                    production_companies  \
# 1466  [Walt Disney Pictures, Jerry Bruckheimer Films...
# 1482    [Walt Disney Pictures, Pixar Animation Studios]
# 377                                    [United Artists]
# 727     [Walt Disney Pictures, Jerry Bruckheimer Films]
# 1058  [Walt Disney Pictures, Jerry Bruckheimer Films...
# 376                                    [United Artists]
# 1562  [Columbia Pictures, Imagenation Abu Dhabi FZ, ...
# 1025  [Columbia Pictures, Revolution Studios, Rogue ...
# 792                     [Laurel Group, Dawn Associates]
# 374                                    [United Artists]
#
#                                                 tagline  \
# 1466                        Live Forever Or Die Trying.
# 1482                                           Ka-ciao!
# 377                                          Go for it!
# 727               Prepare to be blown out of the water.
# 1058     At the end of the world, the adventure begins.
# 376   He's facing the ultimate challenge. And fighti...
# 1562                                    He Rides Again.
# 1025                      It ain't over 'til it's over.
# 792   When there's no more room in hell, the dead wi...
# 374   Once he fought for a dream. Now he's fighting ...
#
#                                                   title  vote_average  \
# 1466        Pirates of the Caribbean: On Stranger Tides           6.4
# 1482                                             Cars 2           5.8
# 377                                             Rocky V           5.3
# 727   Pirates of the Caribbean: The Curse of the Bla...           7.5
# 1058           Pirates of the Caribbean: At World's End           6.9
# 376                                            Rocky IV           6.6
# 1562                   Ghost Rider: Spirit of Vengeance           4.7
# 1025                                       Rocky Balboa           6.5
# 792                                    Dawn of the Dead           7.4
# 374                                            Rocky II           6.9
#
#       vote_count  user_cos_similarity
# 1466        5068             0.134078
# 1482        2088             0.130400
# 377          688             0.123848
# 727         7191             0.121699
# 1058        4627             0.112754
# 376          984             0.110781
# 1562        1163             0.109249
# 1025         858             0.106766
# 792          597             0.098265
# 374          948             0.098217

# %% [markdown]
# ### The same great User-Based suggestions, but random 🥳

# %% [markdown]
# <br>
# <hr>
# <br>
#
# ## ⚠️ So far So good, but our User-Based Recommender System could have ONE downside 😱.
#
# Let me explain, for example, we have a user that is watching/likes `Action` movies as well as `Romance` movies.<br>
#
# in the `figure-2`, at top-right, we have user's `Action` movies, while at the buttom-left we have user's `Romance` movies.<br>
#
# <img src="imgs/figure_2.png" >
#
#
# <b>The issue is when we draw the rectangle of the user's interest, the rectangle is much bigger and contains more movies that the user may not like (out of his interest).</b>
#
# ## So, How are We going to Solve this issue?
#
# ### The perfect approach is to use more accurate movie spaces, to provide more relevant suggestions (see `figure-3`):
#
# <img src="imgs/figure_3.png" >
#
# ### So, Any movies that fall in one of each these circles are great suggestions for that specific user.
#
# <br>

# %% [markdown]
# To achieve this we can use `NearestNeighbors` algorithm from sklearn.

# %%
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import scale


#user = User(28, matrix, min_rating=5)

X = matrix
X_test = user.vectorized_rated_movies()

n, p = X.shape

nn = NearestNeighbors(n_neighbors=3)
nbrs = nn.fit(X)
distances, indices = nbrs.radius_neighbors(X_test, radius=2, return_distance=True, sort_results=True) 


print("X_test: ", X_test.shape)
print("distance:", distances.shape)
print("indices:", indices.shape)

# Filter the important movies indices.
distances = np.array([d[1:5] for d in distances]) # starts from 1 to remove the same movie index.
indices = np.array([d[1:5] for d in indices])     # starts from 1 to remove the same movie index.
# Out:
# X_test:  (10, 16266)
# distance: (10,)
# indices: (10,)

# %%
#display(distances)
display(indices)
# Out:
# array([[ 987, 1366,   22, 1799],
#        [ 377,  376, 2104,  374],
#        [1076,  605, 1566,  445],
#        [1493,  178,  126,  589],
#        [1479, 1445,  583,  422],
#        [ 792,  128,  624, 2115],
#        [1482, 2263, 2038, 1743],
#        [1058,  727, 1466, 1959],
#        [1562, 1029, 1523,  678],
#        [  12, 1646,  861, 1989]])

# %%
import random

# number of movies to choose from, lower is more accurate.
suggestion_range = 30
n_results = 15

l = np.unique(indices.T.ravel())
l = l[:suggestion_range]  # select just most relevant results.
movies_indices = np.array(random.sample(list(l), n_results))
reduced_df.loc[movies_indices]
# Out:
#                                         genres     id  \
# 1482    [Animation, Family, Adventure, Comedy]  49013
# 376                                    [Drama]   1374
# 1466              [Adventure, Action, Fantasy]   1865
# 422                   [Action, Drama, History]    967
# 987   [Comedy, Drama, Family, Music, TV Movie]  10947
# 128                                   [Horror]  10331
# 445              [Adventure, Action, Thriller]    253
# 377                                    [Drama]   1375
# 792                                   [Horror]    923
# 12       [Adventure, Animation, Drama, Family]  10530
# 374                                    [Drama]   1367
# 1029                            [Crime, Drama]   7457
# 727               [Adventure, Fantasy, Action]     22
# 1366                                  [Comedy]  38365
# 1493                                  [Comedy]  49520
#
#                                                overview  \
# 1482  Star race car Lightning McQueen and his pal Ma...
# 376   Rocky must come out of retirement to battle a ...
# 1466  Captain Jack Sparrow crosses paths with a woma...
# 422   Spartacus is a 1960 American historical drama ...
# 987   Troy (Zac Efron), the popular captain of the b...
# 128   A group of people try to survive an attack of ...
# 445   James Bond must investigate a mysterious murde...
# 377   A lifetime of taking shots has ended Rocky's c...
# 792   During an ever-growing epidemic of zombies tha...
# 12    History comes gloriously to life in Disney's e...
# 374   After Rocky goes the distance with champ Apoll...
# 1029  Johnny Truelove likes to see himself as tough....
# 727   Jack Sparrow, a freewheeling 17th-century pira...
# 1366  After their high school basketball coach passe...
# 1493  Dave is a married man with two kids and a lovi...
#
#                                    production_companies  \
# 1482    [Walt Disney Pictures, Pixar Animation Studios]
# 376                                    [United Artists]
# 1466  [Walt Disney Pictures, Jerry Bruckheimer Films...
# 422   [Bryna Productions, Universal International Pi...
# 987                                    [Disney Channel]
# 128   [Laurel Group, Off Color Films, Image Ten, Mar...
# 445           [United Artists, Eon Productions, Danjaq]
# 377                                    [United Artists]
# 792                     [Laurel Group, Dawn Associates]
# 12    [Walt Disney Pictures, Walt Disney Feature Ani...
# 374                                    [United Artists]
# 1029                             [A-Mark Entertainment]
# 727     [Walt Disney Pictures, Jerry Bruckheimer Films]
# 1366  [Columbia Pictures, Happy Madison Productions,...
# 1493  [Universal Pictures, Original Film, Relativity...
#
#                                                 tagline  \
# 1482                                           Ka-ciao!
# 376   He's facing the ultimate challenge. And fighti...
# 1466                        Live Forever Or Die Trying.
# 422              More titanic than any story ever told!
# 987                    This School Rocks Like No Other!
# 128       If it doesn't scare you, you're already dead!
# 445                          Roger Moore is James Bond.
# 377                                          Go for it!
# 792   When there's no more room in hell, the dead wi...
# 12                    An American legend comes to life.
# 374   Once he fought for a dream. Now he's fighting ...
# 1029              One crime. 38 witnesses. No way back.
# 727               Prepare to be blown out of the water.
# 1366    Boys will be boys. . . some longer than others.
# 1493                         Who says men can't change?
#
#                                                   title  vote_average  \
# 1482                                             Cars 2           5.8
# 376                                            Rocky IV           6.6
# 1466        Pirates of the Caribbean: On Stranger Tides           6.4
# 422                                           Spartacus           7.3
# 987                                 High School Musical           6.1
# 128                            Night of the Living Dead           7.5
# 445                                    Live and Let Die           6.4
# 377                                             Rocky V           5.3
# 792                                    Dawn of the Dead           7.4
# 12                                           Pocahontas           6.7
# 374                                            Rocky II           6.9
# 1029                                          Alpha Dog           6.6
# 727   Pirates of the Caribbean: The Curse of the Bla...           7.5
# 1366                                          Grown Ups           6.0
# 1493                                      The Change-Up           5.9
#
#       vote_count
# 1482        2088
# 376          984
# 1466        5068
# 422          472
# 987         1048
# 128          591
# 445          540
# 377          688
# 792          597
# 12          1509
# 374          948
# 1029         463
# 727         7191
# 1366        1746
# 1493         753

# %% [markdown]
# Based on the table/results above, we've got a very relevent suggestions like:
# - Cars 2
# - Rocky IV
# - Rocky V
# - Rocky II
# - Pirates of the Caribbean: On Stranger Tides
# - Pirates of the Caribbean: The Curse of the Bla...
# - Dawn of the Dead
#
# ### Congratulations 😁🎉 , Now our User-Based Recommender System provides more accurate suggestions for any user preferences.
# <br>
# <br>
# <br>

# %% [markdown]
# # 📌 Conclusion
#
# So far, We've discussed various of Recommendation Systems:
# - Classic / simple recommender system.
# - Content-based recommender system.
# - Metadata-based recommender system.
# - User-based recommender system.
#
# Each one of them has Pros and Cons/limitations and its proper use cases.
#
# **In the end, I would like to mention that with AI/Machine Learning, we can create marvelous and much more powerful things 🦾, that will end up elevating the quality of life for humans, and that's the GOAL.**
